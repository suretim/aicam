# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import glob
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models

# =============================
# 超参数
# =============================
DATA_GLOB = "../../../data/*.csv"         # CSV: 每行 [feat1,...,featK,label]；无标签用 -1
SEQ_LEN = 64
FEATURE_DIM = 64                   # 编码器输出维度
BATCH_SIZE = 32

EPOCHS_CONTRASTIVE = 10            # 对比学习预训练轮数（无标签）
EPOCHS_META = 30                   # 元学习轮数（有标签）
INNER_STEPS = 1                    # 任务内微调步数
INNER_LR = 1e-2                    # 任务内学习率
META_LR = 1e-3                     # 元更新学习率
REPTILE_EPS = 0.1                  # Reptile 步长（meta 权重向 task 权重靠拢的比例）

NUM_CLASSES = 3

np.random.seed(42)
tf.random.set_seed(42)

# =============================
# 1) 加载 CSV -> 滑窗样本 + 记录每个窗口的 task_id
#    约定：每个 CSV 代表一个“任务域”（不同植物/环境），便于元学习抽 task
# =============================
X_labeled_list, y_labeled_list, task_id_list = [], [], []
X_unlabeled_list = []

csv_files = sorted(glob.glob(DATA_GLOB))
if len(csv_files) == 0:
    raise FileNotFoundError(f"未找到数据：{DATA_GLOB}")

for tid, file in enumerate(csv_files):
    df = pd.read_csv(file).fillna(-1)  # NaN -> -1 表示无标签
    data = df.values.astype(np.float32)
    feats = data[:, :-1]
    labels = data[:, -1]

    # 构建滑窗
    for i in range(len(data) - SEQ_LEN + 1):
        window_x = feats[i:i+SEQ_LEN]
        window_y = labels[i+SEQ_LEN-1]  # 用窗口末尾的标签
        if window_y == -1:
            X_unlabeled_list.append(window_x)
        else:
            X_labeled_list.append(window_x)
            y_labeled_list.append(int(window_y))
            task_id_list.append(tid)  # 该窗口从哪个 CSV 来

X_unlabeled = np.array(X_unlabeled_list, dtype=np.float32)
if len(X_labeled_list) > 0:
    X_labeled = np.array(X_labeled_list, dtype=np.float32)
    y_labeled = np.array(y_labeled_list, dtype=np.int32)
    task_ids   = np.array(task_id_list,  dtype=np.int32)
    print("有标签样本:", X_labeled.shape, "任务域数:", len(csv_files))
else:
    X_labeled = np.empty((0, SEQ_LEN, X_unlabeled.shape[-1] if len(X_unlabeled)>0 else 3), dtype=np.float32)
    y_labeled = np.empty((0,), dtype=np.int32)
    task_ids  = np.empty((0,), dtype=np.int32)
    print("警告：没有有标签样本，后续仅能做无监督预训练和导出编码器。")

NUM_FEATS = (X_labeled.shape[2] if X_labeled.size>0 else
             (X_unlabeled.shape[2] if X_unlabeled.size>0 else 3))

# =============================
# 2) 对比学习（SimCLR 风格）预训练 LSTM 编码器
# =============================
def augment_window(x):
    # 轻微高斯噪声 + 随机时序丢帧/抖动（简化版）
    x = x + np.random.normal(0, 0.01, x.shape).astype(np.float32)
    return x

def make_contrastive_pairs(X):
    anchors, positives = [], []
    for w in X:
        anchors.append(w)
        positives.append(augment_window(w))
    return np.stack(anchors).astype(np.float32), np.stack(positives).astype(np.float32)

class NTXentLoss(tf.keras.losses.Loss):
    def __init__(self, temperature=0.1):
        super().__init__()
        self.temperature = temperature

    def call(self, z_i, z_j):
        z_i = tf.math.l2_normalize(z_i, axis=1)
        z_j = tf.math.l2_normalize(z_j, axis=1)
        logits = tf.matmul(z_i, z_j, transpose_b=True) / self.temperature
        labels = tf.range(tf.shape(z_i)[0])
        loss_i = tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
        loss_j = tf.keras.losses.sparse_categorical_crossentropy(labels, tf.transpose(logits), from_logits=True)
        return tf.reduce_mean(loss_i + loss_j)

def build_lstm_encoder(seq_len, num_feats, feature_dim=FEATURE_DIM):
    inp = layers.Input(shape=(seq_len, num_feats))
    x = layers.LSTM(feature_dim, return_sequences=False)(inp)
    out = layers.Dense(feature_dim, activation="relu")(x)
    return models.Model(inp, out, name="lstm_encoder")

lstm_encoder = build_lstm_encoder(SEQ_LEN, NUM_FEATS, FEATURE_DIM)
contrastive_opt = tf.keras.optimizers.Adam()

# 若无无标签数据，生成一些随机窗口做预训练
if X_unlabeled.size == 0:
    print("没有无标签数据，生成随机数据用于对比学习预训练……")
    X_unlabeled = np.random.randn(200, SEQ_LEN, NUM_FEATS).astype(np.float32)

anchors, positives = make_contrastive_pairs(X_unlabeled)
contrast_ds = tf.data.Dataset.from_tensor_slices((anchors, positives)).shuffle(2048).batch(BATCH_SIZE)

ntxent = NTXentLoss(temperature=0.2)
for ep in range(EPOCHS_CONTRASTIVE):
    for a, p in contrast_ds:
        with tf.GradientTape() as tape:
            za = lstm_encoder(a, training=True)
            zp = lstm_encoder(p, training=True)
            loss = ntxent(za, zp)
        grads = tape.gradient(loss, lstm_encoder.trainable_variables)
        contrastive_opt.apply_gradients(zip(grads, lstm_encoder.trainable_variables))
    print(f"[Contrastive] Epoch {ep+1}/{EPOCHS_CONTRASTIVE} loss={float(loss.numpy()):.4f}")

# =============================
# 3) 元学习（Reptile）
#    思想：对每个任务，复制模型 -> 在 support 上做若干步微调
#          将 meta 权重朝“任务后权重”移动（平均多个任务）
# =============================
def build_meta_model(encoder, num_classes=NUM_CLASSES):
    # 复制一个具有相同结构的编码器 + 分类头
    inp = layers.Input(shape=(SEQ_LEN, NUM_FEATS))
    x = encoder(inp)  # 使用已有编码器作为 backbone
    x = layers.Dense(32, activation="relu")(x)
    out = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inp, out, name="meta_lstm_classifier")

meta_model = build_meta_model(lstm_encoder, NUM_CLASSES)
meta_optimizer = tf.keras.optimizers.Adam(META_LR)

# 将有标签数据按 task_id 聚合，便于采样任务
task_to_indices = {}
for idx, tid in enumerate(task_ids):
    task_to_indices.setdefault(int(tid), []).append(idx)
task_ids_unique = list(task_to_indices.keys())

def sample_task_batches(X, y, idx_list, batch_size):
    """ 从某任务的样本索引集合中，采一个 batch（用于 support/query） """
    idx = np.random.choice(idx_list, size=min(batch_size, len(idx_list)), replace=False)
    return X[idx], y[idx]

def clone_weights(model):
    return [w.numpy().copy() for w in model.get_weights()]

def assign_weights(model, weights_list):
    model.set_weights(weights_list)

def reptile_meta_step(meta_model, task_ids_unique, inner_steps=INNER_STEPS,
                      inner_lr=INNER_LR, reptile_eps=REPTILE_EPS,
                      support_bs=32, query_bs=64):
    """
    执行一次 Reptile 外层更新：
      1) 采样若干任务
      2) 对每个任务：克隆模型 -> 在 support 上做 inner_steps 次 SGD
      3) 收集任务后权重，meta 权重朝其平均值移动
    """
    if len(task_ids_unique) == 0:
        return  # 没有有标签任务可用

    # 保存 meta 初始权重
    meta_w = clone_weights(meta_model)
    task_weights = []

    for tid in task_ids_unique:
        idx_list = task_to_indices[tid]
        # 克隆一个任务模型（结构相同，复制 meta 当前权重）
        task_model = build_meta_model(lstm_encoder, NUM_CLASSES)
        assign_weights(task_model, meta_w)
        # 任务内优化器（独立于 meta_optimizer）
        inner_opt = tf.keras.optimizers.SGD(learning_rate=inner_lr)

        # inner loop：在该任务的 support 上做若干步
        for _ in range(inner_steps):
            Xs, ys = sample_task_batches(X_labeled, y_labeled, idx_list, support_bs)
            with tf.GradientTape() as tape:
                preds = task_model(Xs, training=True)
                loss = tf.keras.losses.sparse_categorical_crossentropy(ys, preds)
                loss = tf.reduce_mean(loss)
            grads = tape.gradient(loss, task_model.trainable_variables)
            inner_opt.apply_gradients(zip(grads, task_model.trainable_variables))

        # （可选）在 query 上评估一下
        Xq, yq = sample_task_batches(X_labeled, y_labeled, idx_list, query_bs)
        q_preds = task_model(Xq, training=False)
        q_acc = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(q_preds, axis=1), yq), tf.float32))
        print(f"  Task {tid}: query_acc={float(q_acc.numpy()):.3f}")

        # 收集该任务训练后的权重
        task_weights.append(clone_weights(task_model))

    # 将 meta 权重朝各任务权重的平均值靠拢（Reptile 更新）
    avg_task_w = []
    for weights_per_layer in zip(*task_weights):
        avg_task_w.append(np.mean(np.stack(weights_per_layer, axis=0), axis=0))

    # new_meta = meta + eps * (avg_task - meta)
    new_meta_w = [mw + reptile_eps * (aw - mw) for mw, aw in zip(meta_w, avg_task_w)]
    assign_weights(meta_model, new_meta_w)

# ======= 元训练循环 =======
if X_labeled.size > 0:
    for ep in range(EPOCHS_META):
        print(f"[Meta] Epoch {ep+1}/{EPOCHS_META}")
        reptile_meta_step(meta_model, task_ids_unique,
                          inner_steps=INNER_STEPS, inner_lr=INNER_LR,
                          reptile_eps=REPTILE_EPS, support_bs=BATCH_SIZE, query_bs=BATCH_SIZE*2)
else:
    print("跳过元学习：没有有标签数据。")

# =============================
# 4) 可选：在整体验证集上做一个快速评估（把所有有标签样本打乱切分）
# =============================
if X_labeled.size > 0:
    perm = np.random.permutation(len(X_labeled))
    split = int(0.8 * len(perm))
    tr_idx, va_idx = perm[:split], perm[split:]
    Xtr, ytr = X_labeled[tr_idx], y_labeled[tr_idx]
    Xva, yva = X_labeled[va_idx], y_labeled[va_idx]

    # 仅微调最后分类头（模拟 few-shot 适应场景）
    meta_model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                       loss="sparse_categorical_crossentropy",
                       metrics=["accuracy"])
    hist = meta_model.fit(Xtr, ytr, validation_data=(Xva, yva),
                          epochs=5, batch_size=BATCH_SIZE, verbose=1)
    print("Val acc (after short finetune):", hist.history["val_accuracy"][-1])

# =============================
# 5) 导出 TFLite：编码器 + 元分类器
# =============================
def save_tflite(model, out_path):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS,
        tf.lite.OpsSet.SELECT_TF_OPS
    ]
    converter._experimental_lower_tensor_list_ops = False
    tflite_model = converter.convert()
    with open(out_path, "wb") as f:
        f.write(tflite_model)
    print("Saved TFLite:", out_path)

# 独立导出编码器（用于边端只提特征）
save_tflite(lstm_encoder, "lstm_encoder_contrastive.tflite")
# 导出元学习后的端到端分类器（编码器 + 分类头）
if X_labeled.size > 0:
    save_tflite(meta_model, "meta_lstm_classifier.tflite")
# Out:
# 2025-08-18 09:48:41.863521: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 09:48:41.885839: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-18 09:48:42.042788: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-18 09:48:42.044113: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-18 09:48:42.677859: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 有标签样本: (46850, 64, 3) 任务域数: 50
# 没有无标签数据，生成随机数据用于对比学习预训练……
# [Contrastive] Epoch 1/10 loss=0.6130
# [Contrastive] Epoch 2/10 loss=1.0203
# [Contrastive] Epoch 3/10 loss=0.5660
# [Contrastive] Epoch 4/10 loss=0.2677
# [Contrastive] Epoch 5/10 loss=0.1787
# [Contrastive] Epoch 6/10 loss=1.0806
# [Contrastive] Epoch 7/10 loss=0.6971
# [Contrastive] Epoch 8/10 loss=0.1469
# [Contrastive] Epoch 9/10 loss=0.3222
# [Contrastive] Epoch 10/10 loss=0.1427
# [Meta] Epoch 1/30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 220
#     218     for ep in range(EPOCHS_META):
#     219         print(f"[Meta] Epoch {ep+1}/{EPOCHS_META}")
# --> 220         reptile_meta_step(meta_model, task_ids_unique,
#     221                           inner_steps=INNER_STEPS, inner_lr=INNER_LR,
#     222                           reptile_eps=REPTILE_EPS, support_bs=BATCH_SIZE, query_bs=BATCH_SIZE*2)
#     223 else:
#     224     print("跳过元学习：没有有标签数据。")
#
# Cell In[2], line 177, in reptile_meta_step(meta_model, task_ids_unique, inner_steps, inner_lr, reptile_eps, support_bs, query_bs)
#     174     return  # 没有有标签任务可用
#     176 # 保存 meta 初始权重
# --> 177 meta_w = clone_weights(meta_model)
#     178 task_weights = []
#     180 for tid in task_ids_unique:
#
# Cell In[2], line 159, in clone_weights(model)
#     158 def clone_weights(model):
# --> 159     return [w.numpy().copy() for w in model.get_weights()]
#
# Cell In[2], line 159, in <listcomp>(.0)
#     158 def clone_weights(model):
# --> 159     return [w.numpy().copy() for w in model.get_weights()]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'numpy'

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# ==== 参数 ====
DATA_DIR = "./data"
FILE_NAME = "sensor_data_0.csv"   # 可以改成任意一個文件

# ==== 讀取數據 ====
file_path = os.path.join(DATA_DIR, FILE_NAME)
df = pd.read_csv(file_path)

print(f"Loaded {file_path}, shape={df.shape}, stage={df['stage'].iloc[0]}")

# ==== 畫時序圖 ====
fig, axs = plt.subplots(4, 1, figsize=(12, 10), sharex=True)

axs[0].plot(df["temp"], label="Temperature (°C)", color="red")
axs[0].set_ylabel("Temp (°C)")
axs[0].legend(loc="upper right")

axs[1].plot(df["humid"], label="Humidity (%)", color="blue")
axs[1].set_ylabel("Humidity (%)")
axs[1].legend(loc="upper right")

axs[2].plot(df["light"], label="Light (µmol/m²/s)", color="orange")
axs[2].set_ylabel("Light")
axs[2].legend(loc="upper right")

axs[3].plot(df["co2"], label="CO₂ (ppm)", color="green")
axs[3].set_ylabel("CO₂ (ppm)")
axs[3].legend(loc="upper right")

plt.xlabel("Time step")
plt.suptitle(f"Sensor Data Time Series (Stage: {df['stage'].iloc[0]})")
plt.tight_layout()
plt.show()

# ==== 畫標籤分布 ====
plt.figure(figsize=(6, 4))
df["label"].value_counts().sort_index().plot(kind="bar", color="purple")
plt.xticks([0, 1, 2], ["Healthy(0)", "Non-plant(1)", "Unhealthy(2)"])
plt.ylabel("Count")
plt.title(f"Label Distribution in {FILE_NAME}")
plt.show()
# Out:
# Loaded ./data/sensor_data_0.csv, shape=(500, 6), stage=vegetative

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = "./data"
SAVE_PLOTS_DIR = "./plots"
os.makedirs(SAVE_PLOTS_DIR, exist_ok=True)

all_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".csv")]
print(f"Found {len(all_files)} CSV files")

for f in all_files:
    path = os.path.join(DATA_DIR, f)
    df = pd.read_csv(path)
    
    fig, ax1 = plt.subplots(figsize=(12,5))
    
    # 紅藍白光
    ax1.plot(df["light_red"], label="Red", color="red")
    ax1.plot(df["light_blue"], label="Blue", color="blue")
    ax1.plot(df["light_white"], label="White", color="gray")
    ax1.set_xlabel("Time Step")
    ax1.set_ylabel("Light Intensity")
    ax1.legend(loc="upper left")
    
    # CO2 / VPD / pH 共享 x 軸
    ax2 = ax1.twinx()
    ax2.plot(df["co2"], label="CO2", color="green", linestyle="--")
    ax2.plot(df["vpd_kPa"], label="VPD", color="orange", linestyle="--")
    ax2.plot(df["ph"], label="pH", color="purple", linestyle="--")
    ax2.set_ylabel("CO2 / VPD / pH")
    
    # 標題
    plt.title(f"{f} - Light/CO2/VPD/pH")
    ax2.legend(loc="upper right")
    
    # 保存圖表
    plt.tight_layout()
    plot_path = os.path.join(SAVE_PLOTS_DIR, f"{f}_plot.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved plot: {plot_path}")
# Out:
# Found 50 CSV files
# Saved plot: ./plots/sensor_data_0.csv_plot.png
# Saved plot: ./plots/sensor_data_1.csv_plot.png
# Saved plot: ./plots/sensor_data_10.csv_plot.png
# Saved plot: ./plots/sensor_data_11.csv_plot.png
# Saved plot: ./plots/sensor_data_12.csv_plot.png
# Saved plot: ./plots/sensor_data_13.csv_plot.png
# Saved plot: ./plots/sensor_data_14.csv_plot.png
# Saved plot: ./plots/sensor_data_15.csv_plot.png
# Saved plot: ./plots/sensor_data_16.csv_plot.png
# Saved plot: ./plots/sensor_data_17.csv_plot.png
# Saved plot: ./plots/sensor_data_18.csv_plot.png
# Saved plot: ./plots/sensor_data_19.csv_plot.png
# Saved plot: ./plots/sensor_data_2.csv_plot.png
# Saved plot: ./plots/sensor_data_20.csv_plot.png
# Saved plot: ./plots/sensor_data_21.csv_plot.png
# Saved plot: ./plots/sensor_data_22.csv_plot.png
# Saved plot: ./plots/sensor_data_23.csv_plot.png
# Saved plot: ./plots/sensor_data_24.csv_plot.png
# Saved plot: ./plots/sensor_data_25.csv_plot.png
# Saved plot: ./plots/sensor_data_26.csv_plot.png
# Saved plot: ./plots/sensor_data_27.csv_plot.png
# Saved plot: ./plots/sensor_data_28.csv_plot.png
# Saved plot: ./plots/sensor_data_29.csv_plot.png
# Saved plot: ./plots/sensor_data_3.csv_plot.png
# Saved plot: ./plots/sensor_data_30.csv_plot.png
# Saved plot: ./plots/sensor_data_31.csv_plot.png
# Saved plot: ./plots/sensor_data_32.csv_plot.png
# Saved plot: ./plots/sensor_data_33.csv_plot.png
# Saved plot: ./plots/sensor_data_34.csv_plot.png
# Saved plot: ./plots/sensor_data_35.csv_plot.png
# Saved plot: ./plots/sensor_data_36.csv_plot.png
# Saved plot: ./plots/sensor_data_37.csv_plot.png
# Saved plot: ./plots/sensor_data_38.csv_plot.png
# Saved plot: ./plots/sensor_data_39.csv_plot.png
# Saved plot: ./plots/sensor_data_4.csv_plot.png
# Saved plot: ./plots/sensor_data_40.csv_plot.png
# Saved plot: ./plots/sensor_data_41.csv_plot.png
# Saved plot: ./plots/sensor_data_42.csv_plot.png
# Saved plot: ./plots/sensor_data_43.csv_plot.png
# Saved plot: ./plots/sensor_data_44.csv_plot.png
# Saved plot: ./plots/sensor_data_45.csv_plot.png
# Saved plot: ./plots/sensor_data_46.csv_plot.png
# Saved plot: ./plots/sensor_data_47.csv_plot.png
# Saved plot: ./plots/sensor_data_48.csv_plot.png
# Saved plot: ./plots/sensor_data_49.csv_plot.png
# Saved plot: ./plots/sensor_data_5.csv_plot.png
# Saved plot: ./plots/sensor_data_6.csv_plot.png
# Saved plot: ./plots/sensor_data_7.csv_plot.png
# Saved plot: ./plots/sensor_data_8.csv_plot.png
# Saved plot: ./plots/sensor_data_9.csv_plot.png

# %%
import os
import numpy as np
import pandas as pd

SAVE_DIR = "./data"
os.makedirs(SAVE_DIR, exist_ok=True)

NUM_FILES = 50
SEQ_LEN = 500
NOISE_STD = 0.3

# 三階段環境參數
STAGE_PARAMS = [
    {   # seedling
        "temp": (22,26), "humid": (65,75), 
        "light_total":300, "light_ratio":{"red":0.2,"blue":0.6,"white":0.2},
        "co2": (400,600), "ph": (6.0,6.5)
    },
    {   # vegetative
        "temp": (24,28), "humid": (55,65),
        "light_total":600, "light_ratio":{"red":0.4,"blue":0.4,"white":0.2},
        "co2": (800,1200), "ph": (6.0,6.8)
    },
    {   # flowering
        "temp": (20,26), "humid": (45,55),
        "light_total":900, "light_ratio":{"red":0.7,"blue":0.2,"white":0.1},
        "co2": (1000,1500), "ph": (6.2,6.8)
    }
]

def calc_vpd(T,RH):
    SVP = 0.6108 * np.exp((17.27*T)/(T+237.3))
    return SVP*(1 - RH/100)

def flowering_rules(temp, humid, light_red, light_blue, light_white, co2, vpd, ph, male_flower=False):
    li = light_red + light_blue + light_white
    light_wrong = li < 0.8*900 or li > 1.2*900
    ratio_wrong = (light_red/li < 0.6 or light_red/li > 0.8)
    extreme_env = (temp<20 or temp>26 or humid<45 or humid>55 or
                   co2<1000 or co2>1500 or vpd<1.0 or vpd>1.5 or ph<6.2 or ph>6.8)
    if male_flower or light_wrong or ratio_wrong or extreme_env:
        return 2
    else:
        return 0

for i in range(NUM_FILES):
    params = np.random.choice(STAGE_PARAMS)
    t_axis = np.linspace(0, 2*np.pi, SEQ_LEN)
    
    t_base = np.mean(params["temp"])
    h_base = np.mean(params["humid"])
    l_base = params["light_total"]
    co2_base = np.mean(params["co2"])
    ph_base = np.mean(params["ph"])
    
    red_ratio = params["light_ratio"]["red"]
    blue_ratio = params["light_ratio"]["blue"]
    white_ratio = params["light_ratio"]["white"]
    
    t_amp = 3
    h_amp = 5
    l_amp = l_base / 2
    co2_amp = (params["co2"][1] - params["co2"][0])/4
    
    # 基線生成 + 日夜波動 + 噪聲
    temp = t_base + t_amp*np.sin(t_axis) + np.random.randn(SEQ_LEN)*NOISE_STD
    humid = h_base + h_amp*np.cos(t_axis) + np.random.randn(SEQ_LEN)*NOISE_STD
    light_total = l_base + l_amp*np.maximum(0,np.sin(t_axis)) + np.random.randn(SEQ_LEN)*NOISE_STD
    co2 = co2_base + co2_amp*np.sin(2*t_axis) + np.random.randn(SEQ_LEN)*NOISE_STD
    vpd = calc_vpd(temp, humid)
    ph = ph_base + np.random.randn(SEQ_LEN)*0.05
    
    light_red = light_total*red_ratio
    light_blue = light_total*blue_ratio
    light_white = light_total*white_ratio
    
    labels = []
    step = 0
    while step < SEQ_LEN:
        # 模擬肥料機故障連鎖
        fertilizer_fail = np.random.rand() < 0.01
        if fertilizer_fail:
            ph[step:] += np.random.uniform(0.5,1.0)
            co2[step:] += np.random.uniform(-200,200,size=SEQ_LEN-step)
            temp[step:] += np.random.uniform(-3,3,size=SEQ_LEN-step)
            humid[step:] += np.random.uniform(-5,5,size=SEQ_LEN-step)
        
        # 判斷 label
        ti, hi, lr, lb, lw, ci, vp, pi = temp[step], humid[step], light_red[step], light_blue[step], light_white[step], co2[step], vpd[step], ph[step]
        li = lr + lb + lw
        
        if params["light_total"]==900:  # flowering
            male_flower = np.random.rand() < 0.01
            label = flowering_rules(ti, hi, lr, lb, lw, ci, vp, pi, male_flower)
        else:
            if ti<5 or li<50 or ci<300:
                label = 1
            elif (params["temp"][0]<=ti<=params["temp"][1] and
                  params["humid"][0]<=hi<=params["humid"][1] and
                  params["light_total"]*0.95 <= li <= params["light_total"]*1.05 and
                  params["co2"][0]<=ci<=params["co2"][1]):
                label = 0
            else:
                label = 2
        
        labels.append(label)
        step += 1
    
    df = pd.DataFrame({
        "temp": temp,
        "humid": humid,
        "light_red": light_red,
        "light_blue": light_blue,
        "light_white": light_white,
        "co2": co2,
        "vpd_kPa": vpd,
        "ph": ph,
        "label": labels
    })
    
    file_path = os.path.join(SAVE_DIR, f"sensor_data_{i}.csv")
    df.to_csv(file_path, index=False)
    print(f"Saved {file_path}, shape={df.shape}")
# Out:
# Saved ./data/sensor_data_0.csv, shape=(500, 9)
# Saved ./data/sensor_data_1.csv, shape=(500, 9)
# Saved ./data/sensor_data_2.csv, shape=(500, 9)
# Saved ./data/sensor_data_3.csv, shape=(500, 9)
# Saved ./data/sensor_data_4.csv, shape=(500, 9)
# Saved ./data/sensor_data_5.csv, shape=(500, 9)
# Saved ./data/sensor_data_6.csv, shape=(500, 9)
# Saved ./data/sensor_data_7.csv, shape=(500, 9)
# Saved ./data/sensor_data_8.csv, shape=(500, 9)
# Saved ./data/sensor_data_9.csv, shape=(500, 9)
# Saved ./data/sensor_data_10.csv, shape=(500, 9)
# Saved ./data/sensor_data_11.csv, shape=(500, 9)
# Saved ./data/sensor_data_12.csv, shape=(500, 9)
# Saved ./data/sensor_data_13.csv, shape=(500, 9)
# Saved ./data/sensor_data_14.csv, shape=(500, 9)
# Saved ./data/sensor_data_15.csv, shape=(500, 9)
# Saved ./data/sensor_data_16.csv, shape=(500, 9)
# Saved ./data/sensor_data_17.csv, shape=(500, 9)
# Saved ./data/sensor_data_18.csv, shape=(500, 9)
# Saved ./data/sensor_data_19.csv, shape=(500, 9)
# Saved ./data/sensor_data_20.csv, shape=(500, 9)
# Saved ./data/sensor_data_21.csv, shape=(500, 9)
# Saved ./data/sensor_data_22.csv, shape=(500, 9)
# Saved ./data/sensor_data_23.csv, shape=(500, 9)
# Saved ./data/sensor_data_24.csv, shape=(500, 9)
# Saved ./data/sensor_data_25.csv, shape=(500, 9)
# Saved ./data/sensor_data_26.csv, shape=(500, 9)
# Saved ./data/sensor_data_27.csv, shape=(500, 9)
# Saved ./data/sensor_data_28.csv, shape=(500, 9)
# Saved ./data/sensor_data_29.csv, shape=(500, 9)
# Saved ./data/sensor_data_30.csv, shape=(500, 9)
# Saved ./data/sensor_data_31.csv, shape=(500, 9)
# Saved ./data/sensor_data_32.csv, shape=(500, 9)
# Saved ./data/sensor_data_33.csv, shape=(500, 9)
# Saved ./data/sensor_data_34.csv, shape=(500, 9)
# Saved ./data/sensor_data_35.csv, shape=(500, 9)
# Saved ./data/sensor_data_36.csv, shape=(500, 9)
# Saved ./data/sensor_data_37.csv, shape=(500, 9)
# Saved ./data/sensor_data_38.csv, shape=(500, 9)
# Saved ./data/sensor_data_39.csv, shape=(500, 9)
# Saved ./data/sensor_data_40.csv, shape=(500, 9)
# Saved ./data/sensor_data_41.csv, shape=(500, 9)
# Saved ./data/sensor_data_42.csv, shape=(500, 9)
# Saved ./data/sensor_data_43.csv, shape=(500, 9)
# Saved ./data/sensor_data_44.csv, shape=(500, 9)
# Saved ./data/sensor_data_45.csv, shape=(500, 9)
# Saved ./data/sensor_data_46.csv, shape=(500, 9)
# Saved ./data/sensor_data_47.csv, shape=(500, 9)
# Saved ./data/sensor_data_48.csv, shape=(500, 9)
# Saved ./data/sensor_data_49.csv, shape=(500, 9)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = "./data"
SAVE_PLOTS_DIR = "./plots"
os.makedirs(SAVE_PLOTS_DIR, exist_ok=True)

all_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".csv")]
print(f"Found {len(all_files)} CSV files")

for f in all_files:
    path = os.path.join(DATA_DIR, f)
    df = pd.read_csv(path)
    
    fig, ax1 = plt.subplots(figsize=(12,5))
    
    # 紅藍白光
    ax1.plot(df["light_red"], label="Red", color="red")
    ax1.plot(df["light_blue"], label="Blue", color="blue")
    ax1.plot(df["light_white"], label="White", color="gray")
    ax1.set_xlabel("Time Step")
    ax1.set_ylabel("Light Intensity")
    ax1.legend(loc="upper left")
    
    # CO2 / VPD / pH 共享 x 軸
    ax2 = ax1.twinx()
    ax2.plot(df["co2"], label="CO2", color="green", linestyle="--")
    ax2.plot(df["vpd_kPa"], label="VPD", color="orange", linestyle="--")
    ax2.plot(df["ph"], label="pH", color="purple", linestyle="--")
    ax2.set_ylabel("CO2 / VPD / pH")
    
    # 標籤顏色區間
    for lbl, color in zip([0,1,2], ["lime","black","red"]):
        idx = df.index[df["label"]==lbl]
        ax1.scatter(idx, [df["light_red"].max()*1.05]*len(idx), color=color, marker="|", s=100, label=f"Label {lbl}" if f"Label {lbl}" not in [l.get_text() for l in ax1.get_legend().get_texts()] else "")
    
    plt.title(f"{f} - Light/CO2/VPD/pH + Label")
    ax2.legend(loc="upper right")
    
    plt.tight_layout()
    plot_path = os.path.join(SAVE_PLOTS_DIR, f"{f}_plot.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved plot: {plot_path}")
# Out:
# Found 50 CSV files
# Saved plot: ./plots/sensor_data_0.csv_plot.png
# Saved plot: ./plots/sensor_data_1.csv_plot.png
# Saved plot: ./plots/sensor_data_10.csv_plot.png
# Saved plot: ./plots/sensor_data_11.csv_plot.png
# Saved plot: ./plots/sensor_data_12.csv_plot.png
# Saved plot: ./plots/sensor_data_13.csv_plot.png
# Saved plot: ./plots/sensor_data_14.csv_plot.png
# Saved plot: ./plots/sensor_data_15.csv_plot.png
# Saved plot: ./plots/sensor_data_16.csv_plot.png
# Saved plot: ./plots/sensor_data_17.csv_plot.png
# Saved plot: ./plots/sensor_data_18.csv_plot.png
# Saved plot: ./plots/sensor_data_19.csv_plot.png
# Saved plot: ./plots/sensor_data_2.csv_plot.png
# Saved plot: ./plots/sensor_data_20.csv_plot.png
# Saved plot: ./plots/sensor_data_21.csv_plot.png
# Saved plot: ./plots/sensor_data_22.csv_plot.png
# Saved plot: ./plots/sensor_data_23.csv_plot.png
# Saved plot: ./plots/sensor_data_24.csv_plot.png
# Saved plot: ./plots/sensor_data_25.csv_plot.png
# Saved plot: ./plots/sensor_data_26.csv_plot.png
# Saved plot: ./plots/sensor_data_27.csv_plot.png
# Saved plot: ./plots/sensor_data_28.csv_plot.png
# Saved plot: ./plots/sensor_data_29.csv_plot.png
# Saved plot: ./plots/sensor_data_3.csv_plot.png
# Saved plot: ./plots/sensor_data_30.csv_plot.png
# Saved plot: ./plots/sensor_data_31.csv_plot.png
# Saved plot: ./plots/sensor_data_32.csv_plot.png
# Saved plot: ./plots/sensor_data_33.csv_plot.png
# Saved plot: ./plots/sensor_data_34.csv_plot.png
# Saved plot: ./plots/sensor_data_35.csv_plot.png
# Saved plot: ./plots/sensor_data_36.csv_plot.png
# Saved plot: ./plots/sensor_data_37.csv_plot.png
# Saved plot: ./plots/sensor_data_38.csv_plot.png
# Saved plot: ./plots/sensor_data_39.csv_plot.png
# Saved plot: ./plots/sensor_data_4.csv_plot.png
# Saved plot: ./plots/sensor_data_40.csv_plot.png
# Saved plot: ./plots/sensor_data_41.csv_plot.png
# Saved plot: ./plots/sensor_data_42.csv_plot.png
# Saved plot: ./plots/sensor_data_43.csv_plot.png
# Saved plot: ./plots/sensor_data_44.csv_plot.png
# Saved plot: ./plots/sensor_data_45.csv_plot.png
# Saved plot: ./plots/sensor_data_46.csv_plot.png
# Saved plot: ./plots/sensor_data_47.csv_plot.png
# Saved plot: ./plots/sensor_data_48.csv_plot.png
# Saved plot: ./plots/sensor_data_49.csv_plot.png
# Saved plot: ./plots/sensor_data_5.csv_plot.png
# Saved plot: ./plots/sensor_data_6.csv_plot.png
# Saved plot: ./plots/sensor_data_7.csv_plot.png
# Saved plot: ./plots/sensor_data_8.csv_plot.png
# Saved plot: ./plots/sensor_data_9.csv_plot.png

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

DATA_DIR = "./data"
SAVE_PLOTS_DIR = "./flowering_stats"
os.makedirs(SAVE_PLOTS_DIR, exist_ok=True)

all_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".csv")]

for f in all_files:
    path = os.path.join(DATA_DIR, f)
    df = pd.read_csv(path)
    
    # 假設光總量=900表示花期
    if df["light_red"].mean()+df["light_blue"].mean()+df["light_white"].mean() < 850:
        continue  # 非花期
    
    counts = {"male_flower":0, "ph_fail":0, "light_wrong":0, "env_extreme":0}
    
    for idx, row in df.iterrows():
        if row["label"] != 2:
            continue
        # 判斷原因
        li = row["light_red"] + row["light_blue"] + row["light_white"]
        male_flower = np.random.rand() < 0.01  # 同生成規則
        if male_flower:
            counts["male_flower"] += 1
        elif row["ph"] > 6.8 or row["ph"] < 6.2:
            counts["ph_fail"] += 1
        elif li < 0.8*900 or li > 1.2*900 or row["light_red"]/li <0.6 or row["light_red"]/li>0.8:
            counts["light_wrong"] += 1
        elif row["temp"]<20 or row["temp"]>26 or row["humid"]<45 or row["humid"]>55 or row["co2"]<1000 or row["co2"]>1500 or row["vpd_kPa"]<1.0 or row["vpd_kPa"]>1.5:
            counts["env_extreme"] += 1
    
    # 畫柱狀圖
    plt.figure(figsize=(6,4))
    plt.bar(counts.keys(), counts.values(), color=["red","purple","orange","blue"])
    plt.ylabel("Timestep Count")
    plt.title(f"{f} - Flowering Abnormal Events")
    plt.tight_layout()
    
    plot_path = os.path.join(SAVE_PLOTS_DIR, f"{f}_flowering_stats.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Saved {plot_path}, counts={counts}")
# Out:
# Saved ./flowering_stats/sensor_data_11.csv_flowering_stats.png, counts={'male_flower': 2, 'ph_fail': 483, 'light_wrong': 0, 'env_extreme': 8}
# Saved ./flowering_stats/sensor_data_16.csv_flowering_stats.png, counts={'male_flower': 3, 'ph_fail': 461, 'light_wrong': 3, 'env_extreme': 7}
# Saved ./flowering_stats/sensor_data_17.csv_flowering_stats.png, counts={'male_flower': 5, 'ph_fail': 466, 'light_wrong': 0, 'env_extreme': 10}
# Saved ./flowering_stats/sensor_data_18.csv_flowering_stats.png, counts={'male_flower': 1, 'ph_fail': 456, 'light_wrong': 11, 'env_extreme': 8}
# Saved ./flowering_stats/sensor_data_19.csv_flowering_stats.png, counts={'male_flower': 6, 'ph_fail': 488, 'light_wrong': 0, 'env_extreme': 5}
# Saved ./flowering_stats/sensor_data_26.csv_flowering_stats.png, counts={'male_flower': 2, 'ph_fail': 221, 'light_wrong': 183, 'env_extreme': 56}
# Saved ./flowering_stats/sensor_data_28.csv_flowering_stats.png, counts={'male_flower': 7, 'ph_fail': 492, 'light_wrong': 0, 'env_extreme': 0}
# Saved ./flowering_stats/sensor_data_29.csv_flowering_stats.png, counts={'male_flower': 2, 'ph_fail': 94, 'light_wrong': 183, 'env_extreme': 85}
# Saved ./flowering_stats/sensor_data_31.csv_flowering_stats.png, counts={'male_flower': 7, 'ph_fail': 468, 'light_wrong': 0, 'env_extreme': 11}
# Saved ./flowering_stats/sensor_data_32.csv_flowering_stats.png, counts={'male_flower': 4, 'ph_fail': 483, 'light_wrong': 0, 'env_extreme': 7}
# Saved ./flowering_stats/sensor_data_33.csv_flowering_stats.png, counts={'male_flower': 3, 'ph_fail': 278, 'light_wrong': 183, 'env_extreme': 13}
# Saved ./flowering_stats/sensor_data_35.csv_flowering_stats.png, counts={'male_flower': 2, 'ph_fail': 448, 'light_wrong': 17, 'env_extreme': 8}
# Saved ./flowering_stats/sensor_data_37.csv_flowering_stats.png, counts={'male_flower': 7, 'ph_fail': 412, 'light_wrong': 48, 'env_extreme': 12}
# Saved ./flowering_stats/sensor_data_38.csv_flowering_stats.png, counts={'male_flower': 7, 'ph_fail': 295, 'light_wrong': 165, 'env_extreme': 13}
# Saved ./flowering_stats/sensor_data_41.csv_flowering_stats.png, counts={'male_flower': 6, 'ph_fail': 455, 'light_wrong': 6, 'env_extreme': 10}
# Saved ./flowering_stats/sensor_data_42.csv_flowering_stats.png, counts={'male_flower': 5, 'ph_fail': 487, 'light_wrong': 0, 'env_extreme': 3}
# Saved ./flowering_stats/sensor_data_45.csv_flowering_stats.png, counts={'male_flower': 2, 'ph_fail': 452, 'light_wrong': 13, 'env_extreme': 12}

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

DATA_DIR = "./data"
SAVE_REPORT_DIR = "./report"
os.makedirs(SAVE_REPORT_DIR, exist_ok=True)

all_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".csv")]

for f in all_files:
    path = os.path.join(DATA_DIR, f)
    df = pd.read_csv(path)
    
    # ======= 時序圖 =======
    fig, ax1 = plt.subplots(figsize=(12,5))
    
    ax1.plot(df["light_red"], label="Red", color="red")
    ax1.plot(df["light_blue"], label="Blue", color="blue")
    ax1.plot(df["light_white"], label="White", color="gray")
    ax1.set_xlabel("Timestep")
    ax1.set_ylabel("Light Intensity")
    ax1.legend(loc="upper left")
    
    ax2 = ax1.twinx()
    ax2.plot(df["co2"], label="CO2", color="green", linestyle="--")
    ax2.plot(df["vpd_kPa"], label="VPD", color="orange", linestyle="--")
    ax2.plot(df["ph"], label="pH", color="purple", linestyle="--")
    ax2.set_ylabel("CO2 / VPD / pH")
    
    for lbl, color in zip([0,1,2], ["lime","black","red"]):
        idx = df.index[df["label"]==lbl]
        ax1.scatter(idx, [df["light_red"].max()*1.05]*len(idx), color=color, marker="|", s=100,
                    label=f"Label {lbl}" if f"Label {lbl}" not in [l.get_text() for l in ax1.get_legend().get_texts()] else "")
    
    plt.title(f"{f} - Sensor Data + Label")
    ax2.legend(loc="upper right")
    plt.tight_lay_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 39
#      37 plt.title(f"{f} - Sensor Data + Label")
#      38 ax2.legend(loc="upper right")
# ---> 39 plt.tight_lay_
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tight_lay_'
